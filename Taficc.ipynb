# %% [markdown]
# <a href="https://colab.research.google.com/github/Vcode7/Ecg/blob/main/Taficc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install jovian --upgrade -q
# Out:
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.6/68.6 kB 4.2 MB/s eta 0:00:00
# ...

# %%
import jovian

# %%
jovian.set_project('Taffic_management')
